# %%
import numpy as np
import xarray as xr
from modules.ADI import ADI
from modules.integrator import forward_euler_final
from modules.classes import Quantity2D, Analytic
from modules.tests import plot_mass_conservation
import matplotlib.pyplot as plt

# %% [markdown]
# # Initialize a constant diffusion coefficient function
# diffusion = Analytic(lambda x, y: x*y)
# diffusion.set_partial_x(lambda x, y: y)
# diffusion.set_partial_y(lambda x, y: x)

# %%
diffusion = Analytic(lambda x, y: 1)
diffusion.set_partial_x(lambda x, y: 0)
diffusion.set_partial_y(lambda x, y: 0)

# %%
n_grid = 50
n_time = 400
dt = 0.0001
dx = 0.001
dy = 0.001

conc = Quantity2D(
    n_grid,
    n_time,
    (-0.5*n_grid*dx, 0.5*n_grid*dx),
    (-0.5*n_grid*dy, 0.5*n_grid*dy),
    (0, dt*n_time),
)

xcoords = conc.xcoords
ycoords = conc.ycoords
X, Y = np.meshgrid(xcoords, ycoords)
initial_condition =  100*np.exp(- (X**2 + Y**2)/(0.000001*dx*n_grid))
#initial_condition = np.empty_like(X)
#initial_condition[n_grid//2, n_grid//2] = 100

fig = plt.figure()
ax = plt.axes(projection='3d')
ax.plot_surface(X, Y, initial_condition)

# %%
result_ds = forward_euler_final(conc, diffusion, initial_condition)
result_ds
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 result_ds = forward_euler_final(conc, diffusion, initial_condition)
#       2 result_ds
#
# File c:\Users\65948\Documents\A409_SeleniumDispersion\modules\integrator.py:26, in forward_euler_final(C, diffusion, initial_condition)
#      22 set_initial_condition_2D(C, initial_condition)
#      24 for t in np.arange(1, C.n_time):
# ---> 26     forward_euler(C, diffusion)
#      27     zero_dirichlet(C) #figure out the boundary condtions
#      29     C.store_timestep(t)
#
# File c:\Users\65948\Documents\A409_SeleniumDispersion\modules\functions.py:14, in forward_euler(C, diffusion)
#       3 def forward_euler(C, diffusion):
#       4     """Centred difference scheme for 2-D heat equation with varying diffusion coefficient
#       5
#       6     Args:
#    (...)
#      11         dC_dt (ArrayLike): A numpy ndarray for the interior points of the grid (size (N-2) by (N-2))
#      12     """
# ---> 14     C.next[1:-1,1:-1] = C.now[1:-1, 1:-1 ] + C.dt*(diffusion*((C.now[2:, 1:-1] - C.now[1:-1, 1:-1] + C.now[0:-2,1:-1])/C.dx**2 + (C.now[1:-1, 2:] - C.now[1:-1] + C.now[1:-1, 0:-2] )/C.dy**2) + (C.now[2:, 1:-1] - C.now[0:-2])/2*C.dx + (C.now[1:-1, 2:] - C.now[1:-1, 0:-2 ])/2*C.dy)
#
# ValueError: operands could not be broadcast together with shapes (48,48) (48,50)
